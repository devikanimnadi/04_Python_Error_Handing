# %% [markdown]
# <a href="https://colab.research.google.com/github/devikanimnadi/04_Python_Error_Handing/blob/main/Python_Error_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Error Handling**
#
# The computer reads and executes instructions line by line, from top to bottom. The execution of the program will be interrupted at the first error encountered.
# there are two types of errors.
# 1)bugs
# Bugs are mistakes that may not interrupt execution but can cause incorrect behavior.
#
# 2)exceptions
# Exceptions are another category of mistakes in programming. These are specific errors that occur during a program's execution and interrupt its normal flow when first encountered
#
# ##NameError exception
# The variable is not defined.
# ```python
# name="Anna"
# print(age)
# ```
#
# ##SyntaxError exception
# Incorrect syntax
# ```python
# print("Hello)
# ```
#
# ##IndexError
# Out-of-range index
# ```python
# student=["Anna","Bob"]
# print(student[3])
# ```
# ##TypeError exception
# Incorrect type of an argument
# ```python
# len(5)
# ```
# **ValueError exception**
# Inappropriate value
# ```python
# int("hello")
# ```
# ##try/except
# The try block holds code that might cause an exception. If an exception occurs, execution of the try block stops, and the except block is executed, allowing the program to continue running.
#
# ```python
# color = "Green"
# try:
#   print(size)
# except NameError:
#   print("Check the variable name")
# ```
# ```python
# colors = ['Red', 'Yellow', 'Green']
# try:
#   print(colors[10])
# except IndexError:
#   print("Error")
# ```
# ```python
# x=[1,2.3,"Simplilearn"]
# length=0
# i=0
# try:
#   while x[i] :
#     length+=1
#     i+=1
# except IndexError:
#  print(length)
# ```
# ```
# 3
# ```
#
# ##finally
# You can use the finally statement to perform an operation after the try/except block, no matter if an exception occurred or not.
# ```python
# try:
#   print(len(3745))
# except:
#   print("Error")
# finally:
#   print("Save")
# ```
# ```
# Error
# Save
# ```
# ##else
# the else keyword, used with try/except, runs only if the try block is error-free
# ```python
# products = ['ball', 'toy', 'paper']
# try:
#   count = len(products)
# except:
#  print("Error")
# else:
#   print("Count of products:", count)
# ```
# ```
# Count of products:3
# ```
# ##raise statement
# custom exceptions can be triggered using the raise keyword
# ```python
# price = 995
# if price > 500:
#   raise ValueError
# ```
# ```
# ValueError
# ```
# ```python
# temp = -15
# if temp > 50 or temp < -10:
#   raise ValueError("Invalid range")
# ```
# ```
# ValueError: Invalid range
# ```
